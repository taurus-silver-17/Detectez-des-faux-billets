# %%
import pandas as pd 
import numpy as np
import matplotlib as plt
import numpy

# %%
notes=pd.read_csv("notes.csv")
pure=notes.copy()

# %% [markdown]
# # Mission 0
# Afin d'introduire votre analyse, effectuez une brève description des données (analyses univariées et bivariées).

# %%
notes.head()
# Out:
#    is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 0        True    171.81       104.86        104.95        4.52       2.89
# 1        True    171.67       103.74        103.70        4.01       2.87
# 2        True    171.83       103.76        103.76        4.40       2.88
# 3        True    171.80       103.78        103.65        3.73       3.12
# 4        True    172.05       103.70        103.75        5.04       2.27
#
#    length
# 0  112.83
# 1  113.29
# 2  113.84
# 3  113.63
# 4  113.55

# %%
notes.head()
# Out:
#    is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 0        True    171.81       104.86        104.95        4.52       2.89
# 1        True    171.67       103.74        103.70        4.01       2.87
# 2        True    171.83       103.76        103.76        4.40       2.88
# 3        True    171.80       103.78        103.65        3.73       3.12
# 4        True    172.05       103.70        103.75        5.04       2.27
#
#    length
# 0  112.83
# 1  113.29
# 2  113.84
# 3  113.63
# 4  113.55

# %%
notes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170 entries, 0 to 169
# Data columns (total 7 columns):
# is_genuine      170 non-null bool
# diagonal        170 non-null float64
# height_left     170 non-null float64
# height_right    170 non-null float64
# margin_low      170 non-null float64
# margin_up       170 non-null float64
# length          170 non-null float64
# dtypes: bool(1), float64(6)
# memory usage: 8.2 KB

# %%
notes.describe()
# Out:
#          diagonal  height_left  height_right  margin_low   margin_up  \
# count  170.000000   170.000000    170.000000  170.000000  170.000000
# mean   171.940588   104.066353    103.928118    4.612118    3.170412
# std      0.305768     0.298185      0.330980    0.702103    0.236361
# min    171.040000   103.230000    103.140000    3.540000    2.270000
# 25%    171.730000   103.842500    103.690000    4.050000    3.012500
# 50%    171.945000   104.055000    103.950000    4.450000    3.170000
# 75%    172.137500   104.287500    104.170000    5.127500    3.330000
# max    173.010000   104.860000    104.950000    6.280000    3.680000
#
#            length
# count  170.000000
# mean   112.570412
# std      0.924448
# min    109.970000
# 25%    111.855000
# 50%    112.845000
# 75%    113.287500
# max    113.980000

# %%
notes['is_genuine'].unique()
# Out:
# array([ True, False])

# %%
Vrais=notes.loc[notes['is_genuine'].isin([True]),:]

# %%
Vrais.head()
# Out:
#    is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 0        True    171.81       104.86        104.95        4.52       2.89
# 1        True    171.67       103.74        103.70        4.01       2.87
# 2        True    171.83       103.76        103.76        4.40       2.88
# 3        True    171.80       103.78        103.65        3.73       3.12
# 4        True    172.05       103.70        103.75        5.04       2.27
#
#    length
# 0  112.83
# 1  113.29
# 2  113.84
# 3  113.63
# 4  113.55

# %%
Vrais.count()
# Out:
# is_genuine      100
# diagonal        100
# height_left     100
# height_right    100
# margin_low      100
# margin_up       100
# length          100
# dtype: int64

# %%
Vrais.describe()
# Out:
#          diagonal  height_left  height_right  margin_low   margin_up  \
# count  100.000000   100.000000    100.000000  100.000000  100.000000
# mean   171.976100   103.951500    103.775900    4.143500    3.055500
# std      0.307981     0.296251      0.292406    0.314509    0.197726
# min    171.040000   103.230000    103.140000    3.540000    2.270000
# 25%    171.790000   103.740000    103.557500    3.900000    2.937500
# 50%    172.005000   103.915000    103.760000    4.080000    3.070000
# 75%    172.162500   104.145000    103.972500    4.382500    3.192500
# max    172.750000   104.860000    104.950000    5.040000    3.530000
#
#            length
# count  100.000000
# mean   113.207200
# std      0.380476
# min    111.760000
# 25%    112.995000
# 50%    113.210000
# 75%    113.505000
# max    113.980000

# %%
Faux=notes.loc[notes['is_genuine'].isin([False]),:]

# %%
Faux.count()
# Out:
# is_genuine      70
# diagonal        70
# height_left     70
# height_right    70
# margin_low      70
# margin_up       70
# length          70
# dtype: int64

# %%
Faux.describe()
# Out:
#          diagonal  height_left  height_right  margin_low  margin_up  \
# count   70.000000    70.000000     70.000000   70.000000  70.000000
# mean   171.889857   104.230429    104.145571    5.281571   3.334571
# std      0.297426     0.213130      0.253152    0.540846   0.185102
# min    171.380000   103.780000    103.440000    3.820000   2.980000
# 25%    171.682500   104.082500    103.982500    4.952500   3.185000
# 50%    171.875000   104.215000    104.170000    5.265000   3.335000
# 75%    172.047500   104.377500    104.280000    5.702500   3.450000
# max    173.010000   104.720000    104.860000    6.280000   3.680000
#
#            length
# count   70.000000
# mean   111.660714
# std      0.676931
# min    109.970000
# 25%    111.270000
# 50%    111.765000
# 75%    111.985000
# max    113.640000

# %%
notes.head(n=2)
# Out:
#    is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 0        True    171.81       104.86        104.95        4.52       2.89
# 1        True    171.67       103.74        103.70        4.01       2.87
#
#    length
# 0  112.83
# 1  113.29

# %%
notes.boxplot(column='diagonal',by='is_genuine')

# %%
notes.boxplot(column='height_left',by='is_genuine')

# %%
notes.boxplot(column='height_right',by='is_genuine')

# %%
notes.boxplot(column='margin_low',by='is_genuine')

# %%
notes.boxplot(column='margin_up',by='is_genuine')

# %%
notes.boxplot(column='length',by='is_genuine')

# %%
notes.groupby(by='is_genuine').mean()
# Out:
#               diagonal  height_left  height_right  margin_low  margin_up  \
# is_genuine
# False       171.889857   104.230429    104.145571    5.281571   3.334571
# True        171.976100   103.951500    103.775900    4.143500   3.055500
#
#                 length
# is_genuine
# False       111.660714
# True        113.207200

# %% [markdown]
# # Mission 1
# Vous réaliserez une Analyse en Composantes Principales de l'échantillon, en suivant toutes ces étapes :
#
# Analyse de l'éboulis des valeurs propres
# Représentation des variables par le cercle des corrélations
# Représentation des individus par les plans factoriels
# Analyser la qualité de représentation et la contribution des individus.
# Pour chacune de ces étapes, commentez les résultats obtenus. La variable donnant la nature Vrai/Faux du billet sera utilisée comme variable illustrative.

# %% [markdown]
# # ACP

# %%
notes.set_index('is_genuine',inplace=True)

# %%
notes.head(n=2)
# Out:
#             diagonal  height_left  height_right  margin_low  margin_up  length
# is_genuine
# True          171.81       104.86        104.95        4.52       2.89  112.83
# True          171.67       103.74        103.70        4.01       2.87  113.29

# %%
print(notes.columns)
# Out:
# Index(['diagonal', 'height_left', 'height_right', 'margin_low', 'margin_up',
#        'length'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
from sklearn import decomposition
from sklearn import preprocessing
from functions import *

# choix du nombre de composantes à calculer
n_comp = 5

# import de l'échantillon
data = notes[['diagonal', 'height_left', 'height_right', 'margin_low', 'margin_up','length']]

# selection des colonnes à prendre en compte dans l'ACP
data_pca = data[['diagonal', 'height_left', 'height_right', 'margin_low', 'margin_up','length']]

# préparation des données pour l'ACP
#data_pca = data_pca.fillna(data_pca.mean()) # Il est fréquent de remplacer les valeurs inconnues par la moyenne de la variable
X = data_pca.values
names = data.index # ou data.index pour avoir les intitulés
features = data.columns

# Centrage et Réduction
std_scale = preprocessing.StandardScaler().fit(X)
X_scaled = std_scale.transform(X)#ici

# Calcul des composantes principales
pca = decomposition.PCA(n_components=n_comp)
pca.fit(X_scaled)

# Eboulis des valeurs propres
display_scree_plot(pca)

# Cercle des corrélations
pcs = pca.components_
display_circles(pcs, n_comp, pca, [(0,1)], labels = np.array(features))

# Projection des individus
X_projected = pca.transform(X_scaled)#ici
display_factorial_planes(X_projected, n_comp, pca, [(0,1)], illustrative_var=np.array(names))
#display_factorial_planes(X_projected, n_comp, pca, [(0,1)], illustrative_var=pure['is_genuine'])

plt.show()

# %% [markdown]
# # On doit tout d'abord calculer la contribution de l'intertie totale

# %%
from  sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
Z=sc.fit_transform(notes)
print(Z)
# Out:
# [[-0.42834385  2.6694537   3.09656321 -0.13159013 -1.18987367  0.28163308]
#  [-0.88755932 -1.09769709 -0.69125444 -0.86012554 -1.27473985  0.78069736]
#  [-0.36274164 -1.03042654 -0.50943919 -0.30301023 -1.23230676  1.37740465]
#  ...
#  [ 1.73652911  0.68497248  0.52084721  0.38267015  0.67718214 -2.05094997]
#  [-0.39554274 -0.32408577 -0.1458087   0.16839504  1.61071005 -0.75989238]
#  [ 0.06367273 -0.22317994  0.06630909  1.45404575  0.38015054 -1.74717171]]

# %%
di=np.sum(Z**2,axis=1) #Regarder la taille de Z,Di
#print(pd.DataFrame({'ID':notes.index,'d_i':di})).sort_values(by='d_i',ascending=False)
ok=pd.DataFrame({'ID':notes.index,'d_i':di})#.sort_values(by='d_i',ascending=False)

# %%
ok.sort_values(by='d_i',ascending=False)
# Out:
#         ID        d_i
# 166  False  20.625650
# 0     True  18.410598
# 4     True  18.039567
# 122  False  16.790944
# 39    True  15.052608
# 112  False  14.422407
# 151  False  13.637281
# 49    True  12.917538
# 160  False  12.831169
# 158  False  12.724639
# 159  False  12.438171
# 5     True  11.527985
# 70    True  11.048897
# 121  False  10.584966
# 153  False  10.557970
# 147  False  10.500350
# 29    True  10.117561
# 40    True   9.976934
# 75    True   9.847119
# 7     True   9.344338
# 15    True   9.071217
# 142  False   8.995974
# 45    True   8.949829
# 127  False   8.901741
# 137  False   8.812146
# 44    True   8.783168
# 129  False   8.686112
# 131  False   8.616709
# 167  False   8.567410
# 146  False   8.432900
# ..     ...        ...
# 63    True   3.078603
# 30    True   2.940889
# 72    True   2.919323
# 14    True   2.776302
# 71    True   2.747691
# 81    True   2.655658
# 89    True   2.611677
# 102  False   2.482276
# 52    True   2.456750
# ...

# %% [markdown]
# Notre jeu de données "pure" nous servira à observer les répercussions qu'on a sur notre ACP en supprimant certains billets qu'on aura détecté avec la qualité de représentations des individus.

# %%
pure.sort_index()
# Out:
#      is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 0          True    171.81       104.86        104.95        4.52       2.89
# 1          True    171.67       103.74        103.70        4.01       2.87
# 2          True    171.83       103.76        103.76        4.40       2.88
# 3          True    171.80       103.78        103.65        3.73       3.12
# 4          True    172.05       103.70        103.75        5.04       2.27
# 5          True    172.57       104.65        104.44        4.54       2.99
# 6          True    172.38       103.55        103.80        3.97       2.90
# 7          True    171.58       103.65        103.37        3.54       3.19
# 8          True    171.96       103.51        103.75        4.06       3.33
# 9          True    172.14       104.34        104.20        4.63       3.02
# 10         True    172.27       104.29        104.22        3.89       3.53
# ...

# %%
pure=pure.drop(pure.index[11])

# %%
pure.head(n=12)
# Out:
#     is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 0         True    171.81       104.86        104.95        4.52       2.89
# 1         True    171.67       103.74        103.70        4.01       2.87
# 2         True    171.83       103.76        103.76        4.40       2.88
# 3         True    171.80       103.78        103.65        3.73       3.12
# 4         True    172.05       103.70        103.75        5.04       2.27
# 5         True    172.57       104.65        104.44        4.54       2.99
# 6         True    172.38       103.55        103.80        3.97       2.90
# 7         True    171.58       103.65        103.37        3.54       3.19
# 8         True    171.96       103.51        103.75        4.06       3.33
# 9         True    172.14       104.34        104.20        4.63       3.02
# 10        True    172.27       104.29        104.22        3.89       3.53
# ...

# %%
from sklearn.decomposition import PCA
#Instanciation
acp=PCA(svd_solver='full')
print(acp)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#   svd_solver='full', tol=0.0, whiten=False)

# %%
#calculs
coord=acp.fit_transform(notes)

# %% [markdown]
# # Ensuite nous pouvons déduire la qualité de représentation des individus sur l'axe n°k avec :

# %%
#nombre de variables
p=notes.shape[1]
#qualité de représentation des individus - COS2
cos2 = coord**2
for j in range(p):
    cos2[:,j] = cos2[:,j]/di 
print(pd.DataFrame({'id':notes.index,'COS2_1':cos2[:,0],'COS2_2':cos2[:,1]}).sort_values(by='COS2_1'))
# Out:
#         id        COS2_1        COS2_2
# 0     True  4.957420e-07  7.643831e-03
# 65    True  3.070454e-03  1.304295e-04
# 51    True  6.715803e-03  9.686802e-03
# 144  False  7.037218e-03  2.089948e-01
# 80    True  7.539206e-03  7.479679e-02
# 9     True  9.917182e-03  6.973198e-04
# 112  False  1.038201e-02  5.288012e-03
# 70    True  1.099983e-02  6.586088e-03
# 102  False  1.277381e-02  8.603320e-02
# 5     True  1.289523e-02  1.298308e-02
# 43    True  1.402046e-02  7.998105e-04
# 145  False  1.470500e-02  2.946954e-01
# 118  False  1.499952e-02  3.400162e-01
# 33    True  1.509998e-02  6.418996e-03
# 84    True  2.123280e-02  4.817123e-04
# 134  False  2.256976e-02  1.236218e-01
# 106  False  2.570994e-02  2.659118e-02
# 96    True  2.991698e-02  2.362312e-02
# 57    True  3.003811e-02  6.611280e-04
# 4     True  3.052017e-02  5.226348e-02
# 39    True  3.184401e-02  1.099601e-03
# 34    True  3.917673e-02  3.892855e-04
# 44    True  4.222520e-02  2.864659e-02
# ...

# %%
#Ici on observe que le billet 0 est mal représenté et qu'il pourrait "un peu fosser" la #distinction visuelle vrai et faux 
pure=pure.drop(pure.index[0])#donc on va le supprimer

# %%
print(pd.DataFrame({'id':notes.index,'COS2_1':cos2[:,0],'COS2_2':cos2[:,1]}).sort_values(by='COS2_2'))
# Out:
#         id    COS2_1        COS2_2
# 11    True  0.395390  8.993649e-07
# 90    True  0.149231  3.962597e-06
# 8     True  0.227387  4.711665e-05
# 49    True  0.136255  1.003096e-04
# 22    True  0.113332  1.102244e-04
# 154  False  0.381547  1.182013e-04
# 65    True  0.003070  1.304295e-04
# 123  False  0.172407  2.075332e-04
# 124  False  0.117415  2.714030e-04
# 79    True  0.350657  3.003629e-04
# 34    True  0.039177  3.892855e-04
# 129  False  0.083230  4.286890e-04
# 107  False  0.164749  4.406884e-04
# 84    True  0.021233  4.817123e-04
# 56    True  0.051235  6.085348e-04
# 136  False  0.403031  6.150219e-04
# 57    True  0.030038  6.611280e-04
# 9     True  0.009917  6.973198e-04
# 146  False  0.496394  7.002053e-04
# 20    True  0.129744  7.225019e-04
# 165  False  0.164144  7.571822e-04
# 43    True  0.014020  7.998105e-04
# 64    True  0.561308  8.319984e-04
# 1     True  0.187813  8.839756e-04
# 127  False  0.101825  9.738284e-04
# 101  False  0.449814  9.762699e-04
# ...

# %% [markdown]
# Remarques : Après avoir supprimé ce billet et lorsqu'on visualise de nouveau notre ACP mais cette fois ci avec le jeu de donnée "pure" on s'apercoit que le billet qui avait une valeur très petite ne se comportait pas comme son groupe.

# %% [markdown]
# # Mise en place du K-means

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn import decomposition

# Nombre de clusters souhaités
n_clust = 2

# import de l'échantillon
data =notes[['diagonal', 'height_left', 'height_right', 'margin_low', 'margin_up','length']]

# préparation des données pour le clustering
X = data.values

# Réduire n'est ici pas nécessaire car les variables sont exprimées dans la même unité
# X_scaled = preprocessing.StandardScaler().fit_transform(X)

# Clustering par K-means
km = KMeans(n_clusters=n_clust)
km.fit(X)

# Récupération des clusters attribués à chaque individu
clusters = km.labels_

# Affichage du clustering par projection des individus sur le premier plan factoriel
#pca = decomposition.PCA(n_components=3).fit(X)
#X_projected = pca.transform(X)
#plt.scatter(X_projected[:, 0], X_projected[:, 1], c=clusters.astype(np.float), cmap = 'jet', alpha=.2)
#plt.title("Projection des {} individus sur le 1e plan factoriel".format(X_projected.shape[0]))
#plt.show(block=False)

# %%
display_factorial_planes(X_projected, n_comp, pca, [(0,1)],  illustrative_var= np.array(clusters))

plt.show()

# %%
pd.crosstab(clusters,notes.index)
# Out:
# col_0  False  True
# row_0
# 0          2     99
# 1         68      1

# %%
print("Matrice de confusion")
ok = pd.crosstab(clusters,notes.index)
ok.index = ['Cluster 1','Cluster 2']
ok.columns = ['Faux','Vrais']
ok
# Out:
# Matrice de confusion
#            Faux  Vrais
# Cluster 1     2     99
# Cluster 2    68      1

# %% [markdown]
# # Mission 3
# Modélisez les données à l'aide d'une régression logistique. Grâce à celle-ci, vous créerez un programme capable d'effectuer une prédiction sur un billet, c'est-à-dire de déterminer s'il s'agit d'un vrai ou d'un faux billet. Pour chaque billet, votre algorithme de classification devra donner la probabilité que le billet soit vrai. Si cette probabilité est supérieure ou égale à 0.5, le billet sera considéré comme vrai. Dans le cas contraire, il sera considéré comme faux.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import statsmodels.api as sm

# %%
notes=notes.reset_index()

# %%
print(notes.columns)
# Out:
# Index(['is_genuine', 'diagonal', 'height_left', 'height_right', 'margin_low',
#        'margin_up', 'length'],
#       dtype='object')

# %%
notes.head()
# Out:
#    is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 0        True    171.81       104.86        104.95        4.52       2.89
# 1        True    171.67       103.74        103.70        4.01       2.87
# 2        True    171.83       103.76        103.76        4.40       2.88
# 3        True    171.80       103.78        103.65        3.73       3.12
# 4        True    172.05       103.70        103.75        5.04       2.27
#
#    length
# 0  112.83
# 1  113.29
# 2  113.84
# 3  113.63
# 4  113.55

# %%
notes.head()
# Out:
#    is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 0        True    171.81       104.86        104.95        4.52       2.89
# 1        True    171.67       103.74        103.70        4.01       2.87
# 2        True    171.83       103.76        103.76        4.40       2.88
# 3        True    171.80       103.78        103.65        3.73       3.12
# 4        True    172.05       103.70        103.75        5.04       2.27
#
#    length
# 0  112.83
# 1  113.29
# 2  113.84
# 3  113.63
# 4  113.55

# %%
from sklearn.linear_model import LogisticRegression
X = notes.drop(['is_genuine'], axis=1).values
y = notes['is_genuine']

logistic = LogisticRegression()
logistic.fit(X,y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
probabilites = logistic.predict_proba(X)

# %%
probabilites #1ère colonne proba que ce soit faux, 2ème colonne vrai
# Out:
# array([[3.61442842e-01, 6.38557158e-01],
#        [6.45925475e-03, 9.93540745e-01],
#        [6.62840232e-03, 9.93371598e-01],
#        [2.05458371e-03, 9.97945416e-01],
#        [3.12177534e-02, 9.68782247e-01],
#        [1.89342169e-01, 8.10657831e-01],
#        [7.66556838e-03, 9.92334432e-01],
#        [1.49069955e-03, 9.98509300e-01],
#        [8.90693069e-03, 9.91093069e-01],
#        [4.47416215e-01, 5.52583785e-01],
#        [2.23265227e-02, 9.77673477e-01],
#        [2.23437637e-03, 9.97765624e-01],
#        [4.94520041e-02, 9.50547996e-01],
#        [6.39164171e-03, 9.93608358e-01],
#        [6.70734283e-03, 9.93292657e-01],
#        [2.52774963e-02, 9.74722504e-01],
#        [8.48443149e-03, 9.91515569e-01],
#        [2.12455263e-02, 9.78754474e-01],
#        [6.36123293e-03, 9.93638767e-01],
#        [1.35414227e-02, 9.86458577e-01],
#        [2.42838686e-02, 9.75716131e-01],
#        [3.71769907e-02, 9.62823009e-01],
#        [5.09528908e-02, 9.49047109e-01],
# ...

# %%
logistic.predict(X)
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True, False,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False, False,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
# ...

# %%
logistic.coef_ #les coeff de notre équation
# Out:
# array([[-0.37753486, -0.57102422, -1.02979862, -2.81603217, -1.49138411,
#          2.2195641 ]])

# %%
logistic.intercept_ #coeff supplémentaire
# Out:
# array([-0.0065148])

# %%
logistic.predict(X)
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True, False,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False, False,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
# ...

# %%
notes['prediction']=logistic.predict(X)

# %%
pd.crosstab(notes['is_genuine'],notes['prediction'])
# Out:
# prediction  False  True
# is_genuine
# False          69      1
# True            1     99

# %%
(2/170)#taux d'erreur
# Out:
# 0.011764705882352941

# %%
from sklearn.metrics import accuracy_score
accuracy_score(notes['is_genuine'],notes['prediction'])#performance du modele good
# Out:
# 0.9882352941176471

# %% [markdown]
# # Bonus test de la courbe de ROC

# %%
from sklearn import svm, datasets
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %% [markdown]
#  # Chargement du jeu de donnée

# %%
from sklearn.linear_model import LogisticRegression
X = notes.drop(['is_genuine','prediction'], axis=1).values
y = notes['is_genuine']

#test = LogisticRegression()
#test.fit(X,y)

# %% [markdown]
# # Division du jeu de données

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.20, random_state=2)

# %%
 #Modélisation du modèle

# %%
clf = LogisticRegression(penalty='l2', C=0.1)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %% [markdown]
# # Affichage de la précision du modèle

# %%
print("Accuracy", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy 0.9705882352941176

# %% [markdown]
# # Affichage de la courbe

# %%
y_pred_proba = clf.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.show()

# %%
from sklearn.datasets import make_friedman1
from sklearn.feature_selection import RFE
estimator = LogisticRegression()
selector = RFE(estimator, step=1)
selector = selector.fit(X_train, y_train)
selector.support_
# Out:
# array([False, False,  True,  True, False,  True])

# %%
selector.predict(X_test)
# Out:
# array([ True,  True,  True,  True, False,  True,  True, False,  True,
#         True, False,  True,  True, False,  True, False,  True,  True,
#         True, False, False, False, False,  True,  True,  True, False,
#         True, False,  True, False,  True, False, False])

# %%
pd.crosstab(selector.predict(X_test),y_test)
# Out:
# is_genuine  False  True
# row_0
# False          14      0
# True            0     20

# %%
print("Accuracy", metrics.accuracy_score(selector.predict(X_test),y_test))
# Out:
# Accuracy 1.0

# %% [markdown]
# # Mission 4

# %%
#example=pd.read_csv("example.csv")
example=pd.read_csv("test_billets_validation_projet.csv")

# %%
example.head()
# Out:
#    diagonal  height_left  height_right  margin_low  margin_up  length   id
# 0    172.09       103.95        103.73        4.39       3.09  113.19  B_1
# 1    171.52       104.17        104.03        5.27       3.16  111.82  B_2
# 2    171.78       103.80        103.75        3.81       3.24  113.39  B_3
# 3    172.02       104.08        103.99        5.57       3.30  111.10  B_4
# 4    171.79       104.34        104.37        5.00       3.07  111.87  B_5

# %%
from sklearn.linear_model import LogisticRegression
X = example.drop(['id'], axis=1).values
#y = example['id']
#logistic = LogisticRegression()
#logistic.fit(X,y)

# %%
probabilites = selector.predict(X)

# %%
probabilites
# Out:
# array([ True, False,  True, False, False])

# %%
print(pd.DataFrame({'ID':example['id'],'Nature':probabilites}))
# Out:
#     ID  Nature
# 0  B_1    True
# 1  B_2   False
# 2  B_3    True
# 3  B_4   False
# 4  B_5   False

# %%
X_scaled = std_scale.transform(X)#ici
X_projected = pca.transform(X_scaled)#ici
display_factorial_planes(X_projected, n_comp, pca, [(0,1)], illustrative_var=example['id'])
